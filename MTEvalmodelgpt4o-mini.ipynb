# %%
#Loading the devtest files for Flores-200 datasets

import os
import pandas as pd

def load_devtest_files(devtest_directory, specific_files):
    all_data = {}

    for file in specific_files:
        file_path = os.path.join(devtest_directory, file)
        
        if os.path.exists(file_path):
            try:
 
                with open(file_path, 'r', encoding='utf-8') as f:
                    sentences = f.readlines()
                sentences = [sentence.strip() for sentence in sentences if sentence.strip()]  # Remove empty lines and strip whitespace

                all_data[file] = sentences
                print(f"Loaded: {file} with {len(sentences)} sentences")
            except Exception as e:
                print(f"Error loading {file}: {e}")
        else:
            print(f"File not found: {file}")

    return all_data


devtest_directory = r'D:\Machine translation model\flores200_dataset\flores200_dataset\devtest'
specific_files = [
    'eng_Latn.devtest',
    'hin_Deva.devtest',
    'mar_Deva.devtest',
    'guj_Gujr.devtest',
    'ben_Beng.devtest',
    'tel_Telu.devtest',
    'tam_Taml.devtest',
]


loaded_data = load_devtest_files(devtest_directory, specific_files)
# Out:
# Loaded: eng_Latn.devtest with 1012 sentences
# Loaded: hin_Deva.devtest with 1012 sentences
# Loaded: mar_Deva.devtest with 1012 sentences
# Loaded: guj_Gujr.devtest with 1012 sentences
# Loaded: ben_Beng.devtest with 1012 sentences
# Loaded: tel_Telu.devtest with 1012 sentences
# Loaded: tam_Taml.devtest with 1012 sentences

# %%
#Machine translation from English to 5 Indian languages['hin', 'mar', 'guj', 'ben', 'tel', 'tam'] of 150 random samples
#Saving the data into excel files by parallel_dataset_eng_lang

def save_random_samples_to_excel(loaded_data, sample_size=150):
    english_sentences = loaded_data['eng_Latn.devtest']
    
    output_directory = r'D:\Machine translation model\Machine Translation Model\OUTPUT MT'

    sample_size = min(sample_size, len(english_sentences))

    for lang_file, lang_sentences in loaded_data.items():
        if lang_file != 'eng_Latn.devtest':
    
            min_len = min(len(english_sentences), len(lang_sentences))
            if min_len < sample_size:
                print(f"Not enough sentences to sample for {lang_file}. Available: {min_len}")
                continue
            
            english_sample = pd.Series(english_sentences).sample(n=sample_size, random_state=42).reset_index(drop=True)
            lang_sample = pd.Series(lang_sentences).sample(n=sample_size, random_state=42).reset_index(drop=True)

            parallel_df = pd.DataFrame({
                'English': english_sample,
                'Translation': lang_sample
            })

            lang_code = lang_file.split('_')[0]
            excel_filename = os.path.join(output_directory, f'parallel_dataset_eng_{lang_code}.xlsx')
            parallel_df.to_excel(excel_filename, index=False)
            print(f'Saved: {excel_filename} with {len(parallel_df)} entries.')
save_random_samples_to_excel(loaded_data)
# Out:
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_hin.xlsx with 150 entries.
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_mar.xlsx with 150 entries.
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_guj.xlsx with 150 entries.
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_ben.xlsx with 150 entries.
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_tel.xlsx with 150 entries.
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_tam.xlsx with 150 entries.

# %%
#loading the saved excel file of Machine translation

import pandas as pd
import os

def load_parallel_samples(output_directory, languages):
    sampled_data = {}
    for lang_code in languages:
        excel_filename = os.path.join(output_directory, f'parallel_dataset_eng_{lang_code}.xlsx')
        if os.path.exists(excel_filename):
            df = pd.read_excel(excel_filename)
            sampled_data[lang_code] = df
            print(f"Loaded: {excel_filename} with {len(df)} entries.")
        else:
            print(f"File not found: {excel_filename}")
    return sampled_data

output_directory = r'D:\Machine translation model\Machine Translation Model\OUTPUT MT'
languages = ['hin', 'mar', 'guj', 'ben', 'tel', 'tam'] 

sampled_data = load_parallel_samples(output_directory, languages)
# Out:
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_hin.xlsx with 150 entries.
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_mar.xlsx with 150 entries.
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_guj.xlsx with 150 entries.
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_ben.xlsx with 150 entries.
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_tel.xlsx with 150 entries.
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_tam.xlsx with 150 entries.

# %%
import openai
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import pandas as pd
import os
import time

openai.api_key = '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'

def evaluate_translation(english_sentence, actual_translation, target_language):
    prompt = (
        f"Translate the following English sentence into **{target_language} only**, ensuring the translation is natural and fluent. "
        "Please only use one of these languages: Hindi, Marathi, Bengali, Telugu, Gujarati, or Tamil. "
        "Avoid mixing any other languages or dialects in the translation. "
        "Make sure that the translation is grammatically correct and contextually appropriate.\n\n"
        f"English sentence: {english_sentence}\n"
        f"Reference Translation in {target_language}: {actual_translation}\n\n"
        f"Translation in {target_language}:"
    )

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": "You are a multilingual translator."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=500,
            temperature=0.3,
        )
        gpt_translation = response['choices'][0]['message']['content'].strip()  # Direct output, no cleaning
        if gpt_translation:
            # Apply smoothing for BLEU score calculation
            smoothie = SmoothingFunction().method4
            bleu_score = sentence_bleu([actual_translation.split()], gpt_translation.split(), smoothing_function=smoothie)
        else:
            bleu_score = 0
        
        return bleu_score, gpt_translation

    except Exception as e:
        print(f"Error evaluating translation for sentence '{english_sentence}': {e}")
        return 0.0, ""

def evaluate_samples_and_save_to_excel(sampled_data, output_directory):
    for lang_code, data in sampled_data.items():
        target_language = lang_code.split('_')[0]
        english_sentences = data['English']
        actual_translations = data['Translation']

        bleu_scores = []
        gpt_translations = []

        for english_sentence, actual_translation in zip(english_sentences, actual_translations):
            bleu_score, gpt_translation = evaluate_translation(english_sentence, actual_translation, target_language)
            bleu_scores.append(bleu_score)
            gpt_translations.append(gpt_translation)

            print(f"Evaluated: {english_sentence} -> {gpt_translation} | BLEU Score: {bleu_score}")
            time.sleep(1)  # Rate limit handling

        evaluation_df = pd.DataFrame({
            'English': english_sentences,
            'Actual_Translation': actual_translations,
            'GPT_Translation': gpt_translations,
            'BLEU_Score': bleu_scores
        })

        excel_filename = os.path.join(output_directory, f'evaluation_eng_{lang_code}_gpt4omini.xlsx')
        # Use the 'xlsxwriter' engine to ensure UTF-8-SIG encoding
        with pd.ExcelWriter(excel_filename, engine='xlsxwriter') as writer:
            evaluation_df.to_excel(writer, index=False, sheet_name='Evaluation')

        print(f"Saved evaluation results to: {excel_filename}")

# Assuming sampled_data and output_directory are defined
evaluate_samples_and_save_to_excel(sampled_data, output_directory)
# Out:
# Evaluated: Vatican City's population is around 800. It is the smallest independent country in the world and the country with the lowest population. -> वेटिकन सिटी की जनसंख्या लगभग 800 है। यह विश्व का सबसे छोटा स्वतंत्र देश है और सबसे कम जनसंख्या वाला देश भी है। | BLEU Score: 0.45810919659463123
# Evaluated: All citizens of Vatican City are Roman Catholic. -> वेटिकन सिटी के सभी नागरिक रोमन कैथोलिक हैं। | BLEU Score: 0.8408964152537145
# Evaluated: It has a notably wide variety of plant communities, due to its range of microclimates, differing soils and varying levels of altitude. -> इसमें सूक्ष्म जलवायु, भिन्न मिट्टियों और ऊँचाई के विभिन्न स्तरों के कारण उल्लेखनीय रूप से विस्तृत पौधों के समुदायों की विविधता है। | BLEU Score: 0.40902739379830433
# Evaluated: The Amazon River is the second longest and the biggest river on Earth. It carries more than 8 times as much water as the second biggest river. -> अमेज़न नदी धरती की दूसरी सबसे लंबी और सबसे बड़ी नदी है। यह दूसरी सबसे बड़ी नदी से 8 गुना से अधिक पानी ले जाती है। | BLEU Score: 0.6556397462101787
# Evaluated: Lion prides act much like packs of wolves or dogs, animals surprisingly similar to lions (but not other big cats) in behavior, and also very deadly to their prey. -> शेरों का समूह भेड़ियों या कुत्तों के झुंड की तरह काम करता है, जो व्यवहार में शेरों (लेकिन अन्य बड़ी बिल्लियों) के समान होते हैं, और अपने शिकार के लिए बहुत घातक भी होते हैं। | BLEU Score: 0.7080918075521493
# Evaluated: It was one of the major stops during Henry Louis Gates' PBS special Wonders of the African World. -> यह हेनरी लुई गेट्स के पीबीएस विशेष "अफ्रीकी जगत के अजूबे" के दौरान एक प्रमुख पड़ाव था। | BLEU Score: 0.40335820725998883
# Evaluated: Argentina is well known for having one of the best polo teams and players in the world. -> अर्जेंटीना दुनिया में सबसे बेहतरीन पोलो टीमों और खिलाड़ियों के लिए प्रसिद्ध है। | BLEU Score: 0.36883688707312123
# Evaluated: Sleep interruption is the process of purposefully awakening during your normal sleep period and falling asleep a short time later (10–60 minutes). -> नींद की रुकावट आपके सामान्य नींद के दौरान जानबूझकर जागने की प्रक्रिया है और थोड़ी देर बाद (10-60 मिनट) फिर से सो जाना। | BLEU Score: 0.3370260230995962
# Evaluated: For example, “learning” and “socialization” are suggested as important motivations for Internet use (James et al., 1995). -> उदाहरण के लिए, “सीखना” और “सामाजिककरण” को इंटरनेट के उपयोग के लिए महत्वपूर्ण प्रेरणाओं के रूप में सुझाया गया है (जेम्स एट अल., 1995)। | BLEU Score: 0.22656720908801994
# Evaluated: After a week of losses in the midterm election, Bush told an audience about the expansion of trade in Asia. -> मध्यावधि चुनाव में एक हफ्ते की हार के बाद, बुश ने दर्शकों को एशिया में व्यापार के विस्तार के बारे में बताया। | BLEU Score: 0.6888074582865503
# Evaluated: The village of Haldarsvík offer views of the nearby island Eysturoy and has an unusual octagonal church. -> हलडारश्वीक गाँव से पास के एस्टूरॉय का द्वीप नज़र आता है और इसमें एक असाधारण अष्टकोणीय चर्च है। | BLEU Score: 1.0
# Evaluated: It states that the most effective place for the main subject is at the intersection of lines dividing the image into thirds vertically and horizontally (see example). -> यह बताता है कि मुख्य विषय के लिए सबसे प्रभावी स्थान उस चौराहे पर है जहां इमेज को तिरछे और क्षैतिज रूप से तिहाई हिस्सों में विभाजित करने वाली रेखाएँ मिलती हैं (उदाहरण देखें)। | BLEU Score: 0.4571698763985791
# Evaluated: Regular announcements in the Metro are made only in Catalan, but unplanned disruptions are announced by an automated system in a wide variety of languages including Spanish, English, French, Arabic and Japanese. -> मेट्रो में नियमित घोषणाएँ केवल कैटलन में की जाती हैं, लेकिन अनियोजित व्यवधानों की घोषणा एक स्वचालित प्रणाली द्वारा स्पेनिश, अंग्रेजी, फ्रेंच, अरबी और जापानी सहित कई भाषाओं में की जाती है। | BLEU Score: 0.6483396913371388
# Evaluated: One of the main Christian tenets is that wealth should be used to alleviate suffering and poverty and that the monetary funds of the church are there specifically for that reason. -> मुख्य ईसाई सिद्धांतों में से एक यह है कि धन का उपयोग दुख और गरीबी को कम करने के लिए किया जाना चाहिए और चर्च के मौद्रिक कोष विशेष रूप से इसी उद्देश्य के लिए हैं। | BLEU Score: 0.7883286497792379
# Evaluated: NHK also reported that the Kashiwazaki Kariwa nuclear power plant in Niigata prefecture was operating normally. -> एनएचके ने भी सूचना दी कि निगाता प्रांत में काशीवाज़की करिवा परमाणु ऊर्जा संयंत्र सामान्य रूप से काम कर रहा था. | BLEU Score: 1.0
# Evaluated: Fortunately, drivers tend to behave within a reasonably consistent range; thus, traffic streams tend to have some reasonable consistency and can be roughly represented mathematically. -> सौभाग्य से, ड्राइवर एक उचित सुसंगत सीमा के भीतर व्यवहार करते हैं; इस प्रकार, ट्रैफ़िक धाराओं में कुछ उचित स्थिरता होती है और इसे मोटे तौर पर गणितीय रूप से दर्शाया जा सकता है। | BLEU Score: 0.6233837273925882
# Evaluated: Sadly, as newer methods of writing have emerged, the pencil has been relegated to lesser status and uses. -> अफसोस की बात है कि जैसे-जैसे लिखने के नए तरीके सामने आए हैं, पेंसिल की स्थिति और उपयोग कम होते गए हैं। | BLEU Score: 0.29923924292479287
# Evaluated: At the same time, the German navy, using mainly U-boats, was trying to stop this traffic. -> इसके साथ ही जर्मन नौसेना मुख्य रूप से यू-बोट का उपयोग करते हुए इस ट्रैफिक को रोकने की कोशिश कर रही थी। | BLEU Score: 0.8725129388059689
# Evaluated: Using ships to transport goods is by far the most efficient way to move large amounts of people and goods across oceans. -> सामान के परिवहन के लिए जहाज़ों का उपयोग करना समुद्रों के पार बड़ी मात्रा में लोगों और सामान को ले जाने का सबसे प्रभावी तरीका है। | BLEU Score: 0.3277468957316621
# Evaluated: However, the percentage of XDR-TB in the entire group of people with tuberculosis still seems to be low; 6,000 of the total 330,000 people infected at any particular moment in South Africa. -> हालाँकि, ट्यूबरकुलोसिस वाले लोगों के पूरे समूह में एक्सडीआर-टीबी का प्रतिशत अभी भी कम लगता है; दक्षिण अफ़्रीका में किसी विशेष समय पर कुल 330,000 लोगों में से 6,000 संक्रमित हैं। | BLEU Score: 0.7615624524945332
# Evaluated: Due to the underwater topology the return flow is concentrated at a few deeper sections, and a fast current to deep water may form there. -> अंडरवॉटर टोपोलॉजी के कारण रिटर्न फ्लो कुछ गहरे हिस्सों में केंद्रित होता है, और वहां गहरे पानी की ओर तेज़ धारा बन सकती है। | BLEU Score: 0.1502590278683231
# Evaluated: Up means you should start at the tip and push the bow, and down means you should start at the frog (which is where your hand is holding the bow) and pull the bow. -> आगे का मतलब यह है कि आपको शीर्ष से शुरू कर कमान को धकेलना चाहिए और नीचे का मतलब यह है कि आपको फ़्रॉग (जहां आपका हाथ कमान को पकड़ता है) से शुरू कर कमान को खींचना चाहिए। | BLEU Score: 0.6793272817023261
# Evaluated: The cities of Harappa and Mohenjo-daro had a flush toilet in almost every house, attached to a sophisticated sewage system. -> हड़प्पा और मोहन-जोदड़ो के शहरों में लगभग हर घर में एक फ़्लश शौचालय था, जो एक परिष्कृत सीवेज सिस्टम से जुड़ा था। | BLEU Score: 0.9510699415570292
# Evaluated: Authorities speculate that this indicates that containers holding uranium fuel at the site may have ruptured and are leaking. -> अधिकारियों का अनुमान है कि इससे यह संकेत मिलता है कि साइट पर यूरेनियम ईंधन रखने वाले कंटेनर फट गए होंगे और लीक कर रहे होंगे। | BLEU Score: 0.3329634315551654
# Evaluated: Germany was a common enemy in World War 2, leading to cooperation between the USSR and USA. With the end of the war the clashes of system, process and culture led to the countries falling out. -> द्वितीय विश्व युद्ध में जर्मनी एक सामान्य दुश्मन था, जिसने यूएसएसआर और यूएसए के बीच सहयोग को बढ़ावा दिया। युद्ध के अंत के साथ ही प्रणाली, प्रक्रिया और संस्कृति के टकरावों के कारण देशों के बीच मतभेद उत्पन्न होने लगे। | BLEU Score: 0.35231083066040675
# Evaluated: But being placed in the "high tropics" just a few degrees north of equator you will need to deal with both heat (always) and strong sun (when the sky is clear, more rarely). -> लेकिन भूमध्य रेखा के कुछ ही डिग्री उत्तर में मौजूद "उच्च उष्णकटिबंध" में होने के कारण, आपको गर्मी (हमेशा) और तेज़ धूप (जब आसमान साफ़ हो, जो कि कम ही होता है) का सामना करना पड़ेगा। | BLEU Score: 0.663539224838651
# Evaluated: No major damage or injuries have been reported in Tonga, but power was temporarily lost, which reportedly prevented Tongan authorities from receiving the tsunami warning issued by the PTWC. -> टोंगा में कोई बड़ी क्षति या चोट की सूचना नहीं मिली है, लेकिन बिजली अस्थायी रूप से चली गई थी, जिसके कारण कथित तौर पर टोंगन अधिकारियों को पीटीडब्ल्यूसी द्वारा जारी सूनामी चेतावनी प्राप्त करने में बाधा आई थी। | BLEU Score: 0.839843972320263
# Evaluated: It is Martelly's fifth CEP in four years. -> चार साल में यह मार्टेली का पांचवां सीईपी है। | BLEU Score: 1.0
# Evaluated: Hamilton confirmed Howard University Hospital admitted the patient in stable condition. -> हैमिल्टन ने पुष्टि की कि हॉवर्ड यूनिवर्सिटी अस्पताल ने मरीज को स्थिर स्थिति में भर्ती किया। | BLEU Score: 0.8153551038173115
# Evaluated: Bishkek was described as sinking into a state of "anarchy" by one observer, as gangs of people roamed the streets and plundered stores of consumer goods. -> एक पर्यवेक्षक के अनुसार बिश्केक "अराजकता" की स्थिति में डूबता हुआ दिखाई दिया, क्योंकि लोगों के गिरोह सड़कों पर घूम रहे थे और उपभोक्ता वस्तुओं की दुकानों को लूट रहे थे। | BLEU Score: 0.08409847004243719
# Evaluated: The idea of skiing is very old — cave paintings depicting skiers date back as far as 5000 BC! -> स्कीइंग का विचार बहुत पुराना है - गुफा चित्र जो स्कीयरों को दर्शाते हैं, 5000 ईसा पूर्व तक के हैं! | BLEU Score: 0.5468017145144113
# Evaluated: In particular, it is claimed that one can detect whether a person is lying by interpreting micro-expressions correctly. -> विशेष रूप से, यह दावा किया जाता है कि किसी व्यक्ति की सूक्ष्म अभिव्यक्तियों की सही व्याख्या करके यह पता लगाया जा सकता है कि वह झूठ बोल रहा है या नहीं। | BLEU Score: 0.8498644646741501
# Evaluated: Shooters in the supplementary pest control trial were to be closely supervised by rangers, as the trial was monitored and its effectiveness evaluated. -> जैसा कि परीक्षण की निगरानी की गई थी और इसकी प्रभावशीलता का मूल्यांकन किया गया था, उसी तरह पूरक कीट नियंत्रण परीक्षण में निशानेबाज़ों की रेंजरों द्वारा बारीकी से निगरानी की जानी थी। | BLEU Score: 0.9682132340352987
# Evaluated: İzmir is the third largest city in Turkey with a population of around 3.7 million, the second biggest port after Istanbul, and a very good transport hub. -> इज़मिर तुर्की का तीसरा सबसे बड़ा शहर है, जिसकी आबादी लगभग 3.7 मिलियन है, यह इस्तांबुल के बाद दूसरा सबसे बड़ा बंदरगाह है, और एक बहुत अच्छा परिवहन केंद्र है। | BLEU Score: 0.8390782502060267
# Evaluated: During his trip, Iwasaki ran into trouble on many occasions. -> अपनी यात्रा के दौरान, इवासाकी कई मौकों पर मुश्किलों में फंस गया था। | BLEU Score: 0.6703420896351792
# Evaluated: It is related to but usually not involving alpine style ski touring or mountaineering, the latter ones done in steep terrain and requiring much stiffer skis and boots. -> यह संबंधित है, लेकिन आमतौर पर इसमें अल्पाइन शैली की स्की टूरिंग या पर्वतारोहण शामिल नहीं होता है, जो खड़ी जमीन पर किया जाता है और जिसके लिए बहुत कठोर स्की और बूट की आवश्यकता होती है। | BLEU Score: 0.47393517276273106
# Evaluated: Any amendments or requests though should be coursed through the travel agent first and not directly with the hotel. -> कोई भी संशोधन या अनुरोध हालांकि सीधे होटल के साथ नहीं, बल्कि पहले ट्रैवल एजेंट के माध्यम से किया जाना चाहिए। | BLEU Score: 0.617939643800199
# Evaluated: Downhill snowsports, which include skiing and snowboarding, are popular sports involving sliding down snow-covered terrain with skis or a snowboard attached to your feet. -> पहाड़ी ढलान वाले बर्फ के खेल, जिसमें स्कीइंग और स्नोबोर्डिंग शामिल हैं, लोकप्रिय खेल हैं जिनमें बर्फ से ढके इलाके में स्की या स्नोबोर्ड के साथ फिसलना शामिल है। | BLEU Score: 0.6367668795818625
# Evaluated: However, this does not come cheap: as rough rules of thumb, you can expect to pay up to four times the normal economy fare for business, and eleven times for first class! -> हालाँकि, यह सस्ता नहीं है: एक सामान्य नियम के अनुसार, आप बिज़नस के लिए सामान्य इकॉनमी भाड़े का चार गुना तक और प्रथम श्रेणी के लिए ग्यारह गुना तक भुगतान करने की उम्मीद कर सकते हैं! | BLEU Score: 0.8583257606092084
# Evaluated: You may also wish to consult the advice of governments other than your own, but their advice is designed for their citizens. -> आप अपनी सरकार के अलावा अन्य सरकारों की सलाह भी ले सकते हैं, लेकिन उनकी सलाह उनके नागरिकों के लिए होती है। | BLEU Score: 0.24689620584781907
# Evaluated: If you only go ashore using shipboard excursions you will not need a separate visa (as of 2009). -> यदि आप केवल शिपबोर्ड भ्रमण का उपयोग करके किनारे पर जाते हैं, तो आपको एक अलग वीज़ा की आवश्यकता नहीं होगी (2009 तक)। | BLEU Score: 0.747357556981764
# Evaluated: The strain of bird flu lethal to humans, H5N1, has been confirmed to have infected a dead wild duck, found on Monday, in marshland near Lyon in the east of France. -> H5N1, जो मनुष्यों के लिए बर्ड फ्लू का घातक स्ट्रेन है, की पुष्टि की गई है कि यह सोमवार को फ्रांस के पूर्व में ल्योन के पास दलदली क्षेत्र में पाए गए एक मृत जंगली बत्तख को संक्रमित कर चुका है। | BLEU Score: 0.3216031723615536
# Evaluated: Foster care is supposed to provide all the necessities that were lacking in the home they were previously taken from. -> फ़ॉस्टर केयर का उद्देश्य उन सभी आवश्यकताओं को प्रदान करना है जो पहले के घर में कमी थी। | BLEU Score: 0.03591719524005417
# Evaluated: The work done was mostly theoretical, but the program was written to simulate observations made of the Sagittarius galaxy. -> किया गया अधिकांश काम सैद्धांतिक था, लेकिन सैजिटेरियस गैलेक्सी के अवलोकनों का अनुकरण करने के लिए कार्यक्रम लिखा गया था। | BLEU Score: 0.4543439878547469
# Evaluated: Historians have criticized past FBI policies for focusing resources on cases which are easy to solve, especially stolen car cases, with the intent of boosting the agency's success rate. -> इतिहासकारों ने उन मामलों पर संसाधनों को केंद्रित करने के लिए एफबीआई की पिछली नीतियों की आलोचना की है जो हल करना आसान है, विशेष रूप से कार चोरी के मामलों में, एजेंसी की सफलता की दर को बढ़ाने के इरादे से। | BLEU Score: 0.7576593398617909
# Evaluated: A curry is a dish based on herbs and spices, together with either meat or vegetables. -> करी एक ऐसा व्यंजन है जो जड़ी-बूटियों और मसालों के साथ मांस या सब्जियों के मिश्रण पर आधारित होता है। | BLEU Score: 0.21951524426618454
# Evaluated: A binary number can have only one of two values, i.e. 0 or 1, and these numbers are referred to as binary digits - or bits, to use computer jargon. -> किसी बाइनरी संख्या में केवल दो में से एक मान हो सकता है, यानी 0 या 1, और इन संख्याओं को बाइनरी अंक - या कंप्यूटर की भाषा में बिट कहा जाता है। | BLEU Score: 0.6711946312399146
# Evaluated: Despite leaving the show in 1993 he kept the title of executive producer, and continued to receive tens of millions of dollars every season in royalties. -> 1993 में शो छोड़ने के बावजूद उन्होंने एग्जीक्यूटिव प्रोड्यूसर का पद बनाए रखा और हर सीजन में करोड़ों डॉलर की रॉयल्टी प्राप्त करते रहे। | BLEU Score: 0.11326105303471792
# Evaluated: The official Falklands currency is the Falkland pound (FKP) whose value is set equivalent to that of one British pound (GBP). -> फ़ॉकलैंड की आधिकारिक मुद्रा फ़ॉकलैंड पाउंड (एफकेपी) है, जिसकी वैल्यू एक ब्रिटिश पाउंड (जीबीपी) के बराबर निर्धारित की गई है। | BLEU Score: 0.47176896213068414
# Evaluated: The composition of these crystals matches those found in the urine of affected pets when compared by infrared spectroscopy (FTIR). -> जब इंफ्रारेड स्पेक्ट्रोस्कोपी (एफटीआईआर) से इन क्रिस्टलों की संरचना की तुलना की गई, तो ये प्रभावित पालतू जानवरों के मूत्र में पाए जाने वाले क्रिस्टलों से मेल खाते हैं। | BLEU Score: 0.6341066842175741
# Evaluated: Mosasaurus was the apex predator of its time, so it feared nothing, except other mosasaurs. -> मोसासौरस अपने समय का शीर्ष शिकारी था, इसलिए उसे अन्य मोसासौरस के अलावा किसी चीज़ का डर नहीं था। | BLEU Score: 0.6004981752197522
# Evaluated: We make our houses from plants and make clothes from plants. Most foods that we eat are plants. Without plants, animals could not survive. -> हम अपने घरों को पौधों से बनाते हैं और कपड़े पौधों से बनाते हैं। अधिकतर खाद्य पदार्थ जो हम खाते हैं, वो पौधे होते हैं। पौधों के बिना, जानवर जीवित नहीं रह सकते हैं। | BLEU Score: 0.9210500207490827
# Evaluated: Re-entry shock comes on sooner than culture shock (there's less of a honeymoon phase), lasts longer, and can be more severe. -> पुनः प्रवेश झटका सांस्कृतिक झटके की तुलना में जल्दी आता है (हनीमून का चरण कम होता है), यह लंबे समय तक रहता है, और अधिक गंभीर हो सकता है। | BLEU Score: 0.7821998787481578
# Evaluated: A simple popular dinner, especially during the summer, is the Pa amb Oli: Bread with olive oil, tomato, and any available condiments such as cheese, tunafish, etc. -> एक साधारण लोकप्रिय रात का खाना, खासकर गर्मियों में, पा एम्ब ओली है: ब्रेड के साथ जैतून का तेल, टमाटर, और कोई भी उपलब्ध मसाले जैसे पनीर, ट्यूना मछली आदि। | BLEU Score: 0.3530282426205375
# Evaluated: Nothing can be seen other than the clear, beautiful sky above and the many surrounding mountains. Very little of this world can be seen or heard from inside the cave. -> ऊपर साफ़, सुंदर आसमान और चारों ओर के कई पहाड़ों के अलावा और कुछ भी नहीं दिखाई देता। इस गुफ़ा के अंदर से इस दुनिया का बहुत थोड़ा हिस्सा ही देखा या सुना जा सकता है। | BLEU Score: 0.5123496994506979
# Evaluated: The Chaco region was home to other groups of indigenous tribes such as the Guaycurú and Payaguá, who survived by hunting, gathering and fishing. -> चाको क्षेत्र गुइयाकुरू और पेगुआ जैसे अन्य स्वदेशी जनजातियों का घर था, जो शिकार, बीनने और मछली पकड़ने के जरिए जीवित रहते थे। | BLEU Score: 0.15883223299449936
# Evaluated: Research in AI involves making machines to automate tasks that require intelligent behavior. -> एआई में अनुसंधान में ऐसे कार्यों को स्वचालित करने के लिए मशीनें बनाना शामिल है जिनमें बुद्धिमान व्यवहार की आवश्यकता होती है। | BLEU Score: 1.0
# Evaluated: As long as you stay in this zone, you can generally cross borders without going through passport control checkpoints again. -> जब तक आप इस क्षेत्र में रहते हैं, तब तक आप आमतौर पर बिना पासपोर्ट नियंत्रण चौकियों से गुजरे सीमाओं को पार कर सकते हैं। | BLEU Score: 0.7525014264603354
# Evaluated: Your local telephone service provider should be able to give more information about connecting to this service. -> आपका स्थानीय टेलीफोन सेवा प्रदाता इस सेवा से जुड़ने के बारे में अधिक जानकारी प्रदान कर सकता है। | BLEU Score: 0.49925254157379884
# Evaluated: As the areas are sparsely populated, and light pollution therefore often not a problem, you will also be able to enjoy the stars. -> क्षेत्र में जनसंख्या के कम होने और प्रकाश प्रदूषण की समस्या अक्सर न होने के कारण, आप सितारों का भी आनंद ले पाएँगे। | BLEU Score: 0.6449589078615
# Evaluated: If you find yourself resetting the clock in your sleep, it can be placed on the other side of the room, forcing you to get out of bed to turn it off. -> यदि आप खुद को अपनी नींद में घड़ी को रीसेट करते हुए पाते हैं, तो इसे कमरे के दूसरी तरफ रखिए, जिससे आपको इसे बंद करने के लिए बिस्तर से उठना पड़ेगा। | BLEU Score: 0.7563863354400564
# Evaluated: Current senator and Argentine First Lady Cristina Fernandez de Kirchner announced her presidential candidacy yesterday evening in La Plata, a city 50 kilometers (31 miles) away from Buenos Aires. -> वर्तमान सीनेटर और अर्जेंटीना की प्रथम महिला क्रिस्टीना फ़र्नांडीज़ डी किर्चनेर ने कल शाम ब्यूनस आयर्स से 50 किलोमीटर (31 मील) दूर शहर ला प्लाटा में अपने राष्ट्रपति पद की उम्मीदवारी की घोषणा की। | BLEU Score: 0.9691937043892331
# Evaluated: His 1,000th stamp was the magnificent "Great Deeds by Swedish Kings" by David Klöcker Ehrenstrahl in 2000, which is listed in the Guinness Book of World Records. -> डेविड क्लोकर एरेनस्ट्रॉल ने 2000 में अपना 1000वाँ शानदार स्टैंप "ग्रेट डीड्स बाय स्वीडिश किंग्स" बनाया था, जिसे गिनीज बुक ऑफ़ वर्ल्ड रिकॉर्ड में सूचीबद्ध किया गया है। | BLEU Score: 0.5608477095443869
# Evaluated: All things considered, we should not be surprised if our own ancestors solved their "protein problem" in somewhat the same way that chimps on the savanna do today. -> अगर सभी चीजों पर विचार किया जाए, तो हमें आश्चर्यचकित नहीं होना चाहिए अगर हमारे अपने पूर्वजों ने अपनी "प्रोटीन की समस्या" को कुछ हद तक उसी तरह सुलझाया, जैसे आज चिंपांजी सवाना में करते हैं। | BLEU Score: 0.41385470263393187
# Evaluated: The announcement was made after Trump had a phone conversation with Turkish President Recep Tayyip Erdoğan. -> घोषणा ट्रंप और तुर्की के राष्ट्रपति रजब तैयब इरदुगान के बीच फोन पर बातचीत के बाद की गई थी। | BLEU Score: 0.3737280094595172
# Evaluated: Layton had asked for changes to the conservatives' environmental bill during the meeting with the PM, asking for a "thorough and complete rewriting" of the Conservative party's environmental bill. -> लेटन ने पीएम के साथ बैठक के दौरान कंज़र्वेटिव पार्टी के पर्यावरण बिल में बदलाव की मांग की थी, और "पूरी तरह से फिर से लिखने" की बात कही थी। | BLEU Score: 0.3101179734446121
# Evaluated: Duvall, who is married with two adult children, did not leave a big impression on Miller, to whom the story was related. -> डुवैल, जो विवाहित है और उसके दो वयस्क बच्चे हैं, ने मिलर पर बड़ा प्रभाव नहीं डाला, जिसे यह कहानी सुनाई गई थी। | BLEU Score: 0.438257204177357
# Evaluated: Regional and seasonal severe weather phenomena include blizzards, snowstorms, ice storms, and dust storms. -> क्षेत्रीय और मौसमी गंभीर मौसम की घटनाओं में बर्फ़बारी, बर्फ़ीला तूफ़ान, बर्फ़ के तूफान और धूल भरा तूफ़ान शामिल हैं। | BLEU Score: 0.4940911248125205
# Evaluated: Greenland was settled sparsely. In the Norse sagas they say that Erik the Red was exiled from Iceland for murder, and when travelling further west, found Greenland and named it Greenland. -> ग्रीनलैंड को बहुत कम जगह बसाया गया था। नॉर्स सागाओं में कहा गया है कि एरिक द रेड को हत्या के लिए आइसलैंड से निर्वासित किया गया था, और जब वह पश्चिम की ओर यात्रा कर रहा था, तो उसने ग्रीनलैंड पाया और इसका नाम ग्रीनलैंड रखा। | BLEU Score: 0.35510396992797716
# Evaluated: Adekoya has since been in Edinburgh Sheriff Court charged with murdering her son. -> तब से एडेकोया अपने बेटे की हत्या के आरोप में एडिनबर्ग शेरिफ कोर्ट में है। | BLEU Score: 1.0
# Evaluated: The secret to their success is the concept of the niche, a special job each cat holds that keeps it from competing with others. -> उनकी सफलता का रहस्य निच का सिद्धांत है, प्रत्येक बिल्ली के पास एक ख़ास काम होता है जो उसे दूसरों के साथ प्रतिस्पर्धा करने से रोकता है। | BLEU Score: 0.5424340753977054
# Evaluated: Fellow wrestlers also paid tribute to Luna. -> लूना को अन्य पहलवानों ने भी श्रद्धांजलि दी। | BLEU Score: 0.4111336169005197
# Evaluated: According to police, the driver of the vehicle that hit the photographer is unlikely to face criminal charges. -> पुलिस के मुताबिक, फ़ोटोग्राफर को टक्कर मारने वाले वाहन चालक पर आपराधिक आरोप लगने की संभावना बहुत कम है. | BLEU Score: 1.0
# Evaluated: Cochamó Valley - Chile's premier climbing destination, known as the Yosemite of South America, with a variety of granite big walls and crags. -> कोखमो घाटी - चिली का प्रमुख चढ़ाई स्थल है, जिसे दक्षिण अमेरिका का योसेमाइट कहा जाता है, यहाँ ग्रेनाइट की बड़ी दीवारें और चट्टानें हैं। | BLEU Score: 0.13446751467653528
# Evaluated: Sharks do exist, however they rarely attack humans. Most sharks are scared of humans and would swim away. -> शार्कों का अस्तित्व है, हालाँकि वे शायद ही कभी मनुष्यों पर हमला करते हैं। अधिकांश शार्क मनुष्यों से डरती हैं और तैरकर दूर चली जाती हैं। | BLEU Score: 0.6903349550321661
# Saved evaluation results to: D:\Machine translation model\Machine Translation Model\OUTPUT MT\evaluation_eng_hin_gpt4omini.xlsx
# Evaluated: Vatican City's population is around 800. It is the smallest independent country in the world and the country with the lowest population. -> व्हॅटिकन शहराची लोकसंख्या सुमारे 800 आहे. हा जगातील सर्वात छोटा स्वतंत्र देश आहे आणि सर्वात कमी लोकसंख्या असलेला देश आहे. | BLEU Score: 0.8578928092681435
# ...
# Evaluated: The composition of these crystals matches those found in the urine of affected pets when compared by infrared spectroscopy (FTIR). -> இந்த படிகங்களின் கூறுகள், இன்ஃப்ராரெட் ஸ்பெக்ட்ரோஸ்கோபியுடன் (FTIR) ஒப்பிடும்போது பாதிக்கப்பட்ட செல்லப்பிராணிகளின் சிறுநீரில் காணப்படும் கூறுகளுடன் பொருந்துகின்றன. | BLEU Score: 0.6115380576901023
# Evaluated: Also between each dynasty was an unstable age of divided provinces. The best-known of these periods was the Three Kingdoms epoch taking place for 60 years between the Han and the Jin Dynasty. -> ஒவ்வொரு வம்சத்திற்கும் இடையில் மாகாணங்கள் பிரிக்கப்பட்டு ஒரு நிலையற்ற காலம் நிலவி இருந்தது. ஹான் மற்றும் ஜின் வம்சங்களுக்கு இடையில் 60 ஆண்டுகள் நடைபெற்ற மூன்று இராச்சியங்கள் இந்த காலகட்டத்தில் மிகவும் பிரபலமாகக் காணப்படுகிறது. | BLEU Score: 0.5198707241967666
# Evaluated: As a result, two fish species have become extinct, and two others have become endangered, including the humpback chub. -> இதன் விளைவாக, இரண்டு மீன் வகைகள் அழிந்துவிட்டன, மேலும் ஹம்ப்பேக் சப் உட்பட மற்ற இரண்டு அழிக்கும் நிலையில் உள்ளன. | BLEU Score: 0.597735737060173
# Evaluated: Blogs can also help improve student writing. While students often begin their blog experience with sloppy grammar and spelling, the presence of an audience generally changes that. -> வலைப்பதிவுகள் மாணவர்களின் எழுதும் திறனை மேம்படுத்த உதவக்கூடும். மாணவர்கள் பெரும்பாலும் மோசமான இலக்கணம் மற்றும் எழுத்துப்பிழைகளுடன் வலைப்பூ அனுபவத்தை தொடங்குகிறார்கள், ஆனால் பார்வையாளர்களின் இருப்பு பொதுவாக அதை மாற்றிவிடுகிறது. | BLEU Score: 0.35879681831059484
# Evaluated: Why would an organization want to go through the time consuming process of establishing a learning organization? One goal for putting organizational learning concepts into practice is innovation. -> ஒரு கற்கும் நிறுவனத்தை நிறுவுவதற்கான நேரத்தை எடுத்துக்கொள்ளும் செயல்முறைக்கு நிறுவனம் ஏன் செல்ல விரும்புகிறது? நிறுவனக் கற்றல் கருத்துகளை நடைமுறைப்படுத்துவதற்கான ஒரே குறிக்கோள் புதுமை. | BLEU Score: 0.8883547143744179
# Evaluated: As long as you stay in this zone, you can generally cross borders without going through passport control checkpoints again. -> எவ்வளவு காலம் நீங்கள் இந்த பகுதியில் இருக்கிறீர்களோ, அப்போது நீங்கள் பாஸ்போர்ட் கட்டுப்பாடு சோதனைகளை மீண்டும் கடக்காமல் எல்லைகளை கடக்க முடியும். | BLEU Score: 0.24026767328685925
# Evaluated: Your local telephone service provider should be able to give more information about connecting to this service. -> உங்கள் உள்ளூர் தொலைபேசி சேவை வழங்குநர், இந்த சேவையுடன் இணைப்பதற்கான கூடுதல் தகவல்களை வழங்க வேண்டும். | BLEU Score: 0.525045957788985
# Evaluated: As the areas are sparsely populated, and light pollution therefore often not a problem, you will also be able to enjoy the stars. -> பகுதிகள் குறைவாக இருப்பதால், ஒளி மாசுப்பாடு பெரும்பாலும் பிரச்சனையாக இல்லை என்பதால் நீங்கள் நட்சத்திரங்களை அனுபவிக்க முடியும். | BLEU Score: 1.0
# Evaluated: If you find yourself resetting the clock in your sleep, it can be placed on the other side of the room, forcing you to get out of bed to turn it off. -> நீங்கள் தூங்கும் போதே உங்கள் கடிகாரத்தை மறுபடியும் அமைக்கிறீர்கள் என்றால், அதை அறையின் மறுபக்கம் வைத்து, அதை நிறுத்துவதற்கு நீங்கள் படுக்கையிலிருந்து எழுந்து செல்ல வேண்டும். | BLEU Score: 0.32594818888335836
